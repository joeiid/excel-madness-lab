# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px" />
#
# # Excel Madness Lab!
#
# _Author:_ Tim Book

# %% [markdown]
# ## Our Mission
# We work for a large supermarket chain, with stores in 10 major cities that happen to coincide with General Assembly campuses. However, this company's idea of a "database" is just a bunch of Excel spreadsheets! In order to analyze our data, we're going to need to process the existing data into a form we can use. **Our end goal is to have one csv per city.**
#
# ## Cleanup Duty!
# It is a hard truth that data scientists spend a large majority of their time cleaning data. Data never arrives on our desks in exactly the format in which we want it, and it's up to us to transform it to a workable format.
#
# Being good at cleaning, moving, and reshaping data is in itself a valuable and employable job skill. If you follow these directions exactly, we will walk through constructing an automated process for processing data from this supermarket chain.

# %% [markdown]
# # Part I: Processing
#
# ### Step 1: Imports and the `os` library
# We're going to import three libraries: numpy, pandas, and `os`.

# %%
# Import libraries here.
import numpy as np
import pandas as pd
import os

# %% [markdown]
# The `os` library ([https://docs.python.org/3/library/os.html](https://docs.python.org/3/library/os.html)) is extremely useful for performing system commands from within Python. Let's get two pieces of overhead out of the way now:
#
# 1. Create an `output` folder using `os.mkdir()`
# 2. Create a variable called `files` that is the list of files in the `data` folder using `os.listdir()`
#
# **WARNING:** The `os.mkdir()` function will give you an error if you try to make a folder that already exists!

# %%
# Create an output folder.
#os.mkdir('output')

# Create a files variable that contains all of our data files.
files = os.listdir(path = './data')
files
# Out:
# ['Jan 23.xlsx',
#  'Jan 19.xlsx',
#  'Jan 15.xlsx',
#  'Jan 7.xlsx',
#  'Jan 6.xlsx',
#  'Jan 14.xlsx',
#  'Jan 18.xlsx',
#  'Jan 22.xlsx',
#  'Jan 29.xlsx',
#  'Jan 13.xlsx',
#  'Jan 1.xlsx',
#  'Jan 25.xlsx',
#  'Jan 24.xlsx',
#  'Jan 12.xlsx',
#  'Jan 28.xlsx',
#  'Jan 3.xlsx',
#  'Jan 11.xlsx',
#  'Jan 27.xlsx',
#  'Jan 31.xlsx',
#  'Jan 30.xlsx',
#  'Jan 26.xlsx',
#  'Jan 10.xlsx',
#  'Jan 2.xlsx',
#  'Jan 9.xlsx',
#  'Jan 21.xlsx',
#  'Jan 5.xlsx',
#  'Jan 17.xlsx',
#  'Jan 16.xlsx',
#  'Jan 4.xlsx',
#  'Jan 20.xlsx',
#  'Jan 8.xlsx']

# %% [markdown]
# ### Step 2: Process one data frame (one sheet from one file)
# It looks like we have data for the month of January--31 files of 10 sheets each! Luckily they are all in the same format. So let's read just one in and process that. It might be helpful to open one up in your spreadsheet viewer of choice first (Excel, Numbers, Sheets, etc.) to take a look at what you'll be reading in.

# %%
# Read in data from only ONE city (your city or one city of choice) from January 1st.
aust = pd.read_excel('./data/Jan 1.xlsx', sheet_name = 'Austin', engine = 'openpyxl')
aust
# Out:
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#      prodcode  price_eu  weight_kg  quantity
# 0        4796  1.791509   8.226912     361.0
# 1        4134  1.983787   4.373897     257.0
# 2        4272  2.720674   6.675748     173.0
# 3        4796  2.667819   7.856662     151.0
# 4        3302  2.578003   3.237578     151.0
# ..        ...       ...        ...       ...
# 193      4081  1.746767   8.050251     152.0
# 194      4030  2.395127   7.670892     379.0
# 195      4650  0.530046   8.345540     451.0
# 196      4078  0.899691   1.500070     481.0
# 197      4030  0.775880   2.363622     394.0
#
# [198 rows x 4 columns]

# %% [markdown]
# ### Step 2a: Convert to 'Merican columns
# For whatever reason, our data are stored in euros and kilograms. Create `price_usd` and `weight_lb` columns. There are 2.2 pounds per kilogram, and 1.1 dollars per euro.

# %%
aust['price_usd'] = (aust['price_eu'] * 1.1)
aust
# Out:
#      prodcode  price_eu  weight_kg  quantity  price_usd
# 0        4796  1.791509   8.226912     361.0   1.970660
# 1        4134  1.983787   4.373897     257.0   2.182165
# 2        4272  2.720674   6.675748     173.0   2.992741
# 3        4796  2.667819   7.856662     151.0   2.934601
# 4        3302  2.578003   3.237578     151.0   2.835804
# ..        ...       ...        ...       ...        ...
# 193      4081  1.746767   8.050251     152.0   1.921444
# 194      4030  2.395127   7.670892     379.0   2.634639
# 195      4650  0.530046   8.345540     451.0   0.583051
# 196      4078  0.899691   1.500070     481.0   0.989660
# 197      4030  0.775880   2.363622     394.0   0.853468
#
# [198 rows x 5 columns]

# %%
aust['weight_lb'] = (aust['weight_kg'] * 2.2)
aust
# Out:
#      prodcode  price_eu  weight_kg  quantity  price_usd  weight_lb
# 0        4796  1.791509   8.226912     361.0   1.970660  18.099206
# 1        4134  1.983787   4.373897     257.0   2.182165   9.622573
# 2        4272  2.720674   6.675748     173.0   2.992741  14.686645
# 3        4796  2.667819   7.856662     151.0   2.934601  17.284657
# 4        3302  2.578003   3.237578     151.0   2.835804   7.122672
# ..        ...       ...        ...       ...        ...        ...
# 193      4081  1.746767   8.050251     152.0   1.921444  17.710552
# 194      4030  2.395127   7.670892     379.0   2.634639  16.875963
# 195      4650  0.530046   8.345540     451.0   0.583051  18.360188
# 196      4078  0.899691   1.500070     481.0   0.989660   3.300154
# 197      4030  0.775880   2.363622     394.0   0.853468   5.199968
#
# [198 rows x 6 columns]

# %% [markdown]
# ### Step 2b: Merge in product names
# You'll notice we also have a `plu-codes.csv` file containing actual product names matched up against their price lookup (PLU) codes. Let's merge these product names onto our Jan 1 data from above.
# * _Hint 1:_ What kind of merge is this? Right, left, inner, outer, etc.?
# * _Hint 2:_ Pay special attention to column names!

# %%
plu = pd.read_csv("plu-codes.csv")

# %%
plu.head(10)
# Out:
#         product  plu_code
# 0  Apple (Fuji)      4131
# 1  Apple (Gala)      4134
# 2       Apricot      3302
# 3       Avocado      4225
# 4        Banana      4011
# 5   Blueberries      4240
# 6  Strawberries      4323
# 7          Corn      4078
# 8      Cucumber      4062
# 9      Eggplant      4081

# %%
plu = plu.rename(columns={'plu_code': 'prodcode'})
plu.head()
# Out:
#         product  prodcode
# 0  Apple (Fuji)      4131
# 1  Apple (Gala)      4134
# 2       Apricot      3302
# 3       Avocado      4225
# 4        Banana      4011

# %%
aust = pd.merge(aust, plu)
aust
# Out:
#      prodcode  price_eu  weight_kg  quantity  price_usd  weight_lb   product
# 0        4796  1.791509   8.226912     361.0   1.970660  18.099206    Tomato
# 1        4796  2.667819   7.856662     151.0   2.934601  17.284657    Tomato
# 2        4796  2.259230   4.448655     240.0   2.485153   9.787041    Tomato
# 3        4796  0.868427   6.853282     361.0   0.955269  15.077221    Tomato
# 4        4796  0.731746   1.418094     370.0   0.804920   3.119806    Tomato
# ..        ...       ...        ...       ...        ...        ...       ...
# 193      4650  1.340055   2.392355     384.0   1.474060   5.263180  Mushroom
# 194      4650  2.575508   2.323593     272.0   2.833059   5.111904  Mushroom
# 195      4650  1.056409   6.233140     218.0   1.162050  13.712909  Mushroom
# 196      4650  2.340368   6.621807     422.0   2.574404  14.567976  Mushroom
# 197      4650  0.530046   8.345540     451.0   0.583051  18.360188  Mushroom
#
# [198 rows x 7 columns]

# %% [markdown]
# ### Step 2c: Drop unnecessary columns
# We've created some extraneous columns. Drop the old price and weight columns, as well as any redundant columns.

# %%
aust.columns
# Out:
# Index(['prodcode', 'price_eu', 'weight_kg', 'quantity', 'price_usd',
#        'weight_lb', 'product'],
#       dtype='object')

# %%
aust = aust.drop(columns = ['price_eu', 'weight_kg'], axis=True)
aust.columns
# Out:
# Index(['prodcode', 'quantity', 'price_usd', 'weight_lb', 'product'], dtype='object')

# %% [markdown]
# ### Step 2d: Add the date
# Simply create a new `date` column for this dataframe that contains the date this data was collected. For example, this data is from `Jan 1.xlsx`, so this column should be full of `Jan 1`.
# _Note: In this step, this does not need to be an automated function that would assign the relevant date for data from any file. Simply create this one column._

# %%
aust['date'] = 'Jan 1'
aust
# Out:
#      prodcode  quantity  price_usd  weight_lb   product   date
# 0        4796     361.0   1.970660  18.099206    Tomato  Jan 1
# 1        4796     151.0   2.934601  17.284657    Tomato  Jan 1
# 2        4796     240.0   2.485153   9.787041    Tomato  Jan 1
# 3        4796     361.0   0.955269  15.077221    Tomato  Jan 1
# 4        4796     370.0   0.804920   3.119806    Tomato  Jan 1
# ..        ...       ...        ...        ...       ...    ...
# 193      4650     384.0   1.474060   5.263180  Mushroom  Jan 1
# 194      4650     272.0   2.833059   5.111904  Mushroom  Jan 1
# 195      4650     218.0   1.162050  13.712909  Mushroom  Jan 1
# 196      4650     422.0   2.574404  14.567976  Mushroom  Jan 1
# 197      4650     451.0   0.583051  18.360188  Mushroom  Jan 1
#
# [198 rows x 6 columns]

# %% [markdown]
# ### Step 3: Write a function that conducts all of Step 2
# This function should import a **filename and a city name** and return a fully processed DataFrame. That is, the function should:
# 1. Read in the data from the given file and city.
# 1. Create USD and pound columns.
# 1. Merge in product names.
# 1. Drop unnecessary columns.
# 1. Add a date column

# %%
def process_data(file, city):
    data = pd.read_excel('./data/' + file, sheet_name=city)
    data['price_usd'] = round(data['price_eu'] * 1.1, 2)
    data['weight_lb'] = round(data['weight_kg'] * 2.2, 2)
    plu = pd.read_csv("plu-codes.csv")
    plu = plu.rename(columns={'plu_code': 'prodcode'})
    merged_data = pd.merge(data, plu)
    merged_data = merged_data.drop(columns=['price_eu','weight_kg'], axis=True)
    merged_data['date'] = f'{file[:-5]}'

    return merged_data

# %% [markdown]
# Test your function out on a new file and city (one sheet from that file)!

# %%
process_data('Jan 20.xlsx', 'Chicago')
# Out:
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#      prodcode  quantity  price_usd  weight_lb   product    date
# 0        4030     139.0       3.15      14.93      Kiwi  Jan 20
# 1        4030     470.0       2.97       8.70      Kiwi  Jan 20
# 2        4030     368.0       2.78      16.37      Kiwi  Jan 20
# 3        4030     245.0       2.20      19.21      Kiwi  Jan 20
# 4        4030     214.0       3.13       5.33      Kiwi  Jan 20
# ..        ...       ...        ...        ...       ...     ...
# 185      4650     427.0       0.99      21.30  Mushroom  Jan 20
# 186      4650     136.0       1.63      16.83  Mushroom  Jan 20
# 187      4650     152.0       2.98      15.95  Mushroom  Jan 20
# 188      4650     363.0       2.36      14.05  Mushroom  Jan 20
# 189      4650     296.0       1.92       8.20  Mushroom  Jan 20
#
# [190 rows x 6 columns]

# %% [markdown]
# ### Step 4: Process all of January's data for your city
# For each spreadsheet, process the data and store the resulting DataFrame in one big list. **You only need to do this for your city!**
#
# * _Hint 1:_ A listcomp would make this whole step one line of code!
# * _Hint 2:_ You've already made that `files` variable to help you here.

# %%
aust_list = [process_data(x, 'Austin') for x in files]
aust_list
# Out:
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# [     prodcode  quantity  price_usd  weight_lb      product    date
#  0        4412     412.0       1.66      17.25         Pear  Jan 23
#  1        4412     334.0       0.65      10.43         Pear  Jan 23
#  2        4412     130.0       1.02      14.67         Pear  Jan 23
#  3        4412     459.0       0.64      14.20         Pear  Jan 23
#  4        4412     237.0       0.93      12.75         Pear  Jan 23
#  ..        ...       ...        ...        ...          ...     ...
#  106      4958     164.0       2.48       7.00        Lemon  Jan 23
#  107      4240     218.0       0.68       6.95  Blueberries  Jan 23
#  108      4240     244.0       1.49      15.48  Blueberries  Jan 23
#  109      4240     412.0       3.22       6.33  Blueberries  Jan 23
#  110      4240     203.0       1.45      17.77  Blueberries  Jan 23
#
#  [111 rows x 6 columns],
#       prodcode  quantity  price_usd  weight_lb       product    date
#  0        4323     355.0       1.10      16.74  Strawberries  Jan 19
#  1        4323     167.0       1.81       2.22  Strawberries  Jan 19
#  2        4323     363.0       1.47      16.84  Strawberries  Jan 19
#  3        4323     330.0       0.56      11.56  Strawberries  Jan 19
#  4        4323     114.0       1.30       7.61  Strawberries  Jan 19
#  ..        ...       ...        ...        ...           ...     ...
#  169      4412     226.0       0.71      15.08          Pear  Jan 19
#  170      4412     381.0       2.79      12.18          Pear  Jan 19
#  171      4412     472.0       2.43      10.34          Pear  Jan 19
#  172      4412     397.0       3.25      18.19          Pear  Jan 19
#  173      4412     142.0       1.94      11.71          Pear  Jan 19
#
#  [174 rows x 6 columns],
#       prodcode  quantity  price_usd  weight_lb product    date
#  0        4309     406.0       1.40      11.92  Lychee  Jan 15
#  1        4309     305.0       1.38      19.75  Lychee  Jan 15
#  2        4309     141.0       1.84       6.49  Lychee  Jan 15
#  3        4309     443.0       2.45      19.98  Lychee  Jan 15
#  4        4309     496.0       1.02      17.67  Lychee  Jan 15
#  ..        ...       ...        ...        ...     ...     ...
#  164      4078     349.0       0.98       9.48    Corn  Jan 15
#  165      4078     249.0       1.59       4.73    Corn  Jan 15
#  166      4078     396.0       3.00      19.43    Corn  Jan 15
#  167      4078     441.0       1.99      17.40    Corn  Jan 15
#  168      4078     357.0       2.44      20.56    Corn  Jan 15
#
#  [169 rows x 6 columns],
#       prodcode  quantity  price_usd  weight_lb       product   date
#  0        4412     498.0       1.16       7.82          Pear  Jan 7
#  1        4412     192.0       1.70       5.89          Pear  Jan 7
#  2        4412     338.0       2.86       4.64          Pear  Jan 7
#  3        4412     119.0       2.39       9.67          Pear  Jan 7
#  4        4412     193.0       3.12      18.01          Pear  Jan 7
#  ..        ...       ...        ...        ...           ...    ...
#  118      4134     234.0       3.00      21.36  Apple (Gala)  Jan 7
#  119      4225     402.0       2.02      11.05       Avocado  Jan 7
#  120      4159     134.0       2.03      10.95         Onion  Jan 7
#  121      4159     416.0       0.83      13.77         Onion  Jan 7
#  122      4159     465.0       1.42      20.09         Onion  Jan 7
#
#  [123 rows x 6 columns],
#       prodcode  quantity  price_usd  weight_lb      product   date
#  0        4240     285.0       1.97       8.68  Blueberries  Jan 6
#  1        4240     242.0       1.14       8.53  Blueberries  Jan 6
#  2        4240     194.0       1.11      14.94  Blueberries  Jan 6
#  3        4240     192.0       2.65      21.64  Blueberries  Jan 6
#  4        4240     397.0       2.69      16.07  Blueberries  Jan 6
#  ..        ...       ...        ...        ...          ...    ...
#  104      4412     459.0       0.89      20.30         Pear  Jan 6
#  105      4958     374.0       1.28       5.08        Lemon  Jan 6
#  106      4958     111.0       1.16      15.55        Lemon  Jan 6
#  107      4062     449.0       0.87      21.48     Cucumber  Jan 6
#  108      4062     145.0       1.13       9.61     Cucumber  Jan 6
#
#  [109 rows x 6 columns],
#       prodcode  quantity  price_usd  weight_lb       product    date
#  0        4062     208.0       2.64       5.85      Cucumber  Jan 14
#  1        4062     352.0       1.36       8.09      Cucumber  Jan 14
#  2        4062     145.0       1.72      17.82      Cucumber  Jan 14
#  3        4062     302.0       1.42       7.00      Cucumber  Jan 14
#  4        4062     491.0       2.20       6.65      Cucumber  Jan 14
#  ..        ...       ...        ...        ...           ...     ...
#  151      4078     363.0       0.83      15.32          Corn  Jan 14
#  152      4078     379.0       1.27      17.38          Corn  Jan 14
#  153      4131     185.0       3.24      11.66  Apple (Fuji)  Jan 14
#  154      4131     380.0       0.91       6.13  Apple (Fuji)  Jan 14
#  155      4131     443.0       0.78      17.69  Apple (Fuji)  Jan 14
#
#  [156 rows x 6 columns],
#       prodcode  quantity  price_usd  weight_lb       product    date
#  0        4272     261.0       2.61      16.40        Grapes  Jan 18
#  1        4272     369.0       1.98      11.41        Grapes  Jan 18
#  2        4272     412.0       2.78      10.40        Grapes  Jan 18
#  3        4134     483.0       2.55      12.09  Apple (Gala)  Jan 18
#  4        4134     277.0       0.77      13.25  Apple (Gala)  Jan 18
#  ..        ...       ...        ...        ...           ...     ...
#  124      4309     446.0       2.43      18.99        Lychee  Jan 18
#  125      4323     396.0       2.40      13.18  Strawberries  Jan 18
#  126      4323     165.0       1.08      19.67  Strawberries  Jan 18
#  127      4323     497.0       2.25      14.42  Strawberries  Jan 18
#  128      4323     338.0       1.19       7.44  Strawberries  Jan 18
#
#  [129 rows x 6 columns],
#       prodcode  quantity  price_usd  weight_lb product    date
#  0        4012     232.0       1.36      20.22  Orange  Jan 22
#  1        4012     292.0       2.88      16.47  Orange  Jan 22
#  2        4012     278.0       2.52      18.76  Orange  Jan 22
#  3        4012     179.0       2.89      16.59  Orange  Jan 22
#  4        4012     298.0       1.28       3.43  Orange  Jan 22
#  ..        ...       ...        ...        ...     ...     ...
#  167      4404     382.0       1.50      20.38   Peach  Jan 22
#  168      4404     182.0       1.03      12.16   Peach  Jan 22
#  169      4404     180.0       2.46       8.60   Peach  Jan 22
#  170      4404     453.0       3.15       3.02   Peach  Jan 22
#  171      4404     360.0       2.47       8.35   Peach  Jan 22
#
#  [172 rows x 6 columns],
#       prodcode  quantity  price_usd  weight_lb   product    date
#  0        4030     261.0       1.88       2.95      Kiwi  Jan 29
#  1        4030     177.0       1.11       4.94      Kiwi  Jan 29
#  2        4030     416.0       2.66      15.05      Kiwi  Jan 29
#  3        4030     174.0       2.02       9.09      Kiwi  Jan 29
#  4        4030     152.0       2.03      18.97      Kiwi  Jan 29
#  ..        ...       ...        ...        ...       ...     ...
#  181      4650     222.0       1.25       8.97  Mushroom  Jan 29
#  182      4650     497.0       1.06       2.86  Mushroom  Jan 29
#  183      4650     382.0       0.58      18.76  Mushroom  Jan 29
#  184      4650     168.0       1.35      10.36  Mushroom  Jan 29
#  185      4650     484.0       1.80      15.56  Mushroom  Jan 29
#
#  [186 rows x 6 columns],
#       prodcode  quantity  price_usd  weight_lb   product    date
#  0        4958     331.0       2.35       8.42     Lemon  Jan 13
#  1        4958     242.0       1.41       3.21     Lemon  Jan 13
#  2        4958     180.0       2.60       4.66     Lemon  Jan 13
#  3        4958     395.0       1.17      18.30     Lemon  Jan 13
#  4        4958     161.0       1.06      18.73     Lemon  Jan 13
#  ..        ...       ...        ...        ...       ...     ...
#  153      4062     419.0       1.91       2.27  Cucumber  Jan 13
#  154      4078     270.0       1.07      16.09      Corn  Jan 13
#  155      4078     249.0       0.98       8.42      Corn  Jan 13
#  156      4078     186.0       1.00      11.77      Corn  Jan 13
#  157      4078     405.0       2.63      13.53      Corn  Jan 13
#
#  [158 rows x 6 columns],
#       prodcode  quantity  price_usd  weight_lb   product   date
#  0        4796     361.0       1.97      18.10    Tomato  Jan 1
#  1        4796     151.0       2.93      17.28    Tomato  Jan 1
#  2        4796     240.0       2.49       9.79    Tomato  Jan 1
#  3        4796     361.0       0.96      15.08    Tomato  Jan 1
#  4        4796     370.0       0.80       3.12    Tomato  Jan 1
#  ..        ...       ...        ...        ...       ...    ...
#  193      4650     384.0       1.47       5.26  Mushroom  Jan 1
#  194      4650     272.0       2.83       5.11  Mushroom  Jan 1
#  195      4650     218.0       1.16      13.71  Mushroom  Jan 1
#  196      4650     422.0       2.57      14.57  Mushroom  Jan 1
#  197      4650     451.0       0.58      18.36  Mushroom  Jan 1
#
#  [198 rows x 6 columns],
#       prodcode  quantity  price_usd  weight_lb       product    date
#  0        4134     204.0       1.83       2.79  Apple (Gala)  Jan 25
#  1        4134     433.0       0.71      12.65  Apple (Gala)  Jan 25
#  2        4134     384.0       2.82      21.31  Apple (Gala)  Jan 25
#  3        4131     180.0       2.13      14.47  Apple (Fuji)  Jan 25
#  4        4131     100.0       1.64       5.02  Apple (Fuji)  Jan 25
#  ..        ...       ...        ...        ...           ...     ...
#  193      4240     277.0       1.58       2.67   Blueberries  Jan 25
#  194      4240     434.0       0.90      11.08   Blueberries  Jan 25
#  195      4240     422.0       2.19      10.87   Blueberries  Jan 25
#  196      4240     166.0       1.31       2.36   Blueberries  Jan 25
#  197      4240     496.0       0.75       2.57   Blueberries  Jan 25
#
#  [198 rows x 6 columns],
#       prodcode  quantity  price_usd  weight_lb   product    date
#  0        4062     304.0       1.52      13.91  Cucumber  Jan 24
#  1        4062     180.0       2.93      17.28  Cucumber  Jan 24
#  2        4062     287.0       2.53      21.16  Cucumber  Jan 24
#  3        4062     143.0       1.97      20.20  Cucumber  Jan 24
#  4        4062     234.0       0.58      19.71  Cucumber  Jan 24
#  ..        ...       ...        ...        ...       ...     ...
#  96       4011     405.0       3.17       6.47    Banana  Jan 24
#  97       3302     475.0       0.99      20.58   Apricot  Jan 24
#  98       3302     170.0       2.69       5.13   Apricot  Jan 24
#  99       4272     238.0       2.02       8.72    Grapes  Jan 24
#  100      4272     388.0       2.45      19.97    Grapes  Jan 24
#
#  [101 rows x 6 columns],
#       prodcode  quantity  price_usd  weight_lb       product    date
#  0        4134     184.0       2.60       8.44  Apple (Gala)  Jan 12
#  1        4134     438.0       2.31       7.89  Apple (Gala)  Jan 12
#  2        4134     344.0       2.02       7.31  Apple (Gala)  Jan 12
#  3        4134     310.0       2.90      13.60  Apple (Gala)  Jan 12
#  4        4134     131.0       1.24      13.34  Apple (Gala)  Jan 12
#  ..        ...       ...        ...        ...           ...     ...
#  174      4309     197.0       0.66      11.86        Lychee  Jan 12
#  175      4309     304.0       1.12       9.88        Lychee  Jan 12
#  176      4309     131.0       0.97       4.52        Lychee  Jan 12
#  177      4309     485.0       1.03      20.46        Lychee  Jan 12
#  178      4309     296.0       1.21       4.14        Lychee  Jan 12
#
#  [179 rows x 6 columns],
#       prodcode  quantity  price_usd  weight_lb       product    date
#  0        4323     396.0       2.28      12.81  Strawberries  Jan 28
#  1        4323     190.0       1.86       9.52  Strawberries  Jan 28
#  2        4323     490.0       2.05      19.23  Strawberries  Jan 28
#  3        4323     222.0       2.20      18.17  Strawberries  Jan 28
#  4        4323     188.0       2.60      14.48  Strawberries  Jan 28
#  ..        ...       ...        ...        ...           ...     ...
#  104      4062     146.0       1.77      18.51      Cucumber  Jan 28
#  105      4062     467.0       2.47       3.38      Cucumber  Jan 28
#  106      4062     370.0       3.17       4.63      Cucumber  Jan 28
#  107      4062     379.0       1.55      16.44      Cucumber  Jan 28
#  108      4062     122.0       3.02       6.12      Cucumber  Jan 28
#
#  [109 rows x 6 columns],
#       prodcode  quantity  price_usd  weight_lb product   date
#  0        4272     365.0       1.12       6.65  Grapes  Jan 3
#  1        4272     223.0       2.79      17.59  Grapes  Jan 3
#  2        4272     418.0       1.87       5.25  Grapes  Jan 3
#  3        4272     345.0       2.17      18.34  Grapes  Jan 3
#  4        4272     223.0       2.46      12.12  Grapes  Jan 3
#  ..        ...       ...        ...        ...     ...    ...
#  160      4012     253.0       1.86      19.91  Orange  Jan 3
#  161      4012     180.0       1.48       3.41  Orange  Jan 3
#  162      4012     407.0       2.56       7.36  Orange  Jan 3
#  163      4012     322.0       2.90      18.37  Orange  Jan 3
#  164      4012     287.0       1.42      19.08  Orange  Jan 3
#
#  [165 rows x 6 columns],
#       prodcode  quantity  price_usd  weight_lb       product    date
#  0        4404     183.0       1.55      17.38         Peach  Jan 11
#  1        4404     402.0       2.76      11.40         Peach  Jan 11
#  2        4404     128.0       2.87      20.99         Peach  Jan 11
#  3        4404     133.0       1.52      17.59         Peach  Jan 11
#  4        4404     270.0       3.23      18.70         Peach  Jan 11
#  ..        ...       ...        ...        ...           ...     ...
#  142      4134     476.0       2.56       4.51  Apple (Gala)  Jan 11
#  143      4650     456.0       0.76       8.76      Mushroom  Jan 11
#  144      4650     148.0       1.32       9.69      Mushroom  Jan 11
#  145      4650     348.0       2.36      21.78      Mushroom  Jan 11
#  146      4650     107.0       1.10       7.91      Mushroom  Jan 11
#
#  [147 rows x 6 columns],
#       prodcode  quantity  price_usd  weight_lb   product    date
#  0        4272     192.0       1.32      18.46    Grapes  Jan 27
#  1        4272     214.0       1.00      16.86    Grapes  Jan 27
#  2        4272     461.0       3.24      12.20    Grapes  Jan 27
#  3        4272     101.0       1.30       8.29    Grapes  Jan 27
#  4        4650     159.0       2.16      11.90  Mushroom  Jan 27
#  ..        ...       ...        ...        ...       ...     ...
#  115      4796     150.0       2.89      16.61    Tomato  Jan 27
#  116      4796     160.0       3.08      10.98    Tomato  Jan 27
#  117      4030     382.0       1.42       7.49      Kiwi  Jan 27
#  118      4030     307.0       1.90      20.57      Kiwi  Jan 27
#  119      4030     132.0       2.74       8.64      Kiwi  Jan 27
#
#  [120 rows x 6 columns],
#       prodcode  quantity  price_usd  weight_lb   product    date
#  0        4062     338.0       1.78       9.25  Cucumber  Jan 31
#  1        4062     439.0       3.26       3.95  Cucumber  Jan 31
#  2        4062     200.0       0.59       5.55  Cucumber  Jan 31
#  3        4062     356.0       3.00      15.67  Cucumber  Jan 31
#  4        4062     161.0       2.65      15.64  Cucumber  Jan 31
#  ..        ...       ...        ...        ...       ...     ...
#  184      4412     267.0       2.21       3.13      Pear  Jan 31
#  185      4412     350.0       3.19      17.05      Pear  Jan 31
#  186      4412     280.0       1.90       8.37      Pear  Jan 31
#  187      4412     197.0       2.92      16.20      Pear  Jan 31
#  188      4412     435.0       1.23      14.59      Pear  Jan 31
#
#  [189 rows x 6 columns],
#       prodcode  quantity  price_usd  weight_lb       product    date
#  0        4404     269.0       3.12       4.27         Peach  Jan 30
#  1        4404     408.0       1.47       4.61         Peach  Jan 30
#  2        4404     379.0       3.10      17.89         Peach  Jan 30
#  3        4404     413.0       1.21       5.10         Peach  Jan 30
#  4        4404     125.0       1.60      21.90         Peach  Jan 30
#  ..        ...       ...        ...        ...           ...     ...
#  147      4323     430.0       1.60      17.16  Strawberries  Jan 30
#  148      4323     268.0       0.80      14.79  Strawberries  Jan 30
#  149      4323     307.0       0.95       7.45  Strawberries  Jan 30
#  150      4225     220.0       1.35       2.85       Avocado  Jan 30
#  151      4225     244.0       1.59       3.75       Avocado  Jan 30
#
#  [152 rows x 6 columns],
#       prodcode  quantity  price_usd  weight_lb       product    date
#  0        4225     107.0       1.37      15.08       Avocado  Jan 26
#  1        4225     183.0       3.01      15.34       Avocado  Jan 26
#  2        4225     263.0       2.66       4.15       Avocado  Jan 26
#  3        4225     413.0       0.65       3.29       Avocado  Jan 26
#  4        4225     429.0       2.04      11.52       Avocado  Jan 26
#  ..        ...       ...        ...        ...           ...     ...
#  126      4650     366.0       1.98       8.66      Mushroom  Jan 26
#  127      4131     245.0       2.95      16.85  Apple (Fuji)  Jan 26
#  128      4131     139.0       0.91       4.86  Apple (Fuji)  Jan 26
#  129      4131     249.0       2.45       6.78  Apple (Fuji)  Jan 26
#  130      4131     484.0       2.01      12.13  Apple (Fuji)  Jan 26
#
#  [131 rows x 6 columns],
#       prodcode  quantity  price_usd  weight_lb   product    date
#  0        4081     419.0       2.07      20.38  Eggplant  Jan 10
#  1        4081     126.0       1.33      19.49  Eggplant  Jan 10
#  2        4081     470.0       2.47       6.95  Eggplant  Jan 10
#  3        4081     394.0       1.54       9.25  Eggplant  Jan 10
#  4        4081     365.0       1.93      19.62  Eggplant  Jan 10
#  ..        ...       ...        ...        ...       ...     ...
#  164      4272     231.0       2.03       4.59    Grapes  Jan 10
#  165      4272     404.0       0.72      13.01    Grapes  Jan 10
#  166      4272     475.0       2.60      15.36    Grapes  Jan 10
#  167      4272     138.0       2.06      16.46    Grapes  Jan 10
#  168      4272     153.0       3.06      21.37    Grapes  Jan 10
#
#  [169 rows x 6 columns],
#       prodcode  quantity  price_usd  weight_lb  product   date
#  0        4225     469.0       2.41      13.51  Avocado  Jan 2
#  1        4225     202.0       2.49      13.51  Avocado  Jan 2
#  2        4225     442.0       2.09      13.96  Avocado  Jan 2
#  3        4225     187.0       0.63      18.25  Avocado  Jan 2
#  4        4225     179.0       0.73       8.74  Avocado  Jan 2
#  ..        ...       ...        ...        ...      ...    ...
#  172      4796     379.0       2.99       4.91   Tomato  Jan 2
#  173      4796     390.0       0.82      17.39   Tomato  Jan 2
#  174      4796     340.0       1.64      15.01   Tomato  Jan 2
#  175      4796     200.0       2.74      12.21   Tomato  Jan 2
#  176      4796     308.0       1.80       2.37   Tomato  Jan 2
#
#  [177 rows x 6 columns],
#       prodcode  quantity  price_usd  weight_lb  product   date
#  0        4404     234.0       2.55      20.45    Peach  Jan 9
#  1        4404     272.0       1.43       4.03    Peach  Jan 9
#  2        4404     340.0       1.98       3.39    Peach  Jan 9
#  3        4404     308.0       1.62      21.20    Peach  Jan 9
#  4        4404     114.0       2.64      14.85    Peach  Jan 9
#  ..        ...       ...        ...        ...      ...    ...
#  194      4225     166.0       1.18      10.92  Avocado  Jan 9
#  195      4225     408.0       0.68      12.75  Avocado  Jan 9
#  196      4225     329.0       3.11       8.86  Avocado  Jan 9
#  197      4225     330.0       1.70      19.72  Avocado  Jan 9
#  198      4225     341.0       2.97      17.24  Avocado  Jan 9
#
#  [199 rows x 6 columns],
#      prodcode  quantity  price_usd  weight_lb       product    date
#  0       4225     436.0       2.45      16.47       Avocado  Jan 21
#  1       4225     284.0       1.68       2.79       Avocado  Jan 21
#  2       4225     268.0       0.75       3.56       Avocado  Jan 21
#  3       4323     211.0       2.12      11.33  Strawberries  Jan 21
#  4       4323     147.0       3.26       2.45  Strawberries  Jan 21
#  ..       ...       ...        ...        ...           ...     ...
#  95      4796     451.0       1.47       3.42        Tomato  Jan 21
#  96      4078     260.0       1.40       4.16          Corn  Jan 21
#  97      4078     117.0       2.48       8.06          Corn  Jan 21
#  98      4078     376.0       1.54       5.67          Corn  Jan 21
#  99      4078     496.0       2.86       8.35          Corn  Jan 21
#
#  [100 rows x 6 columns],
#       prodcode  quantity  price_usd  weight_lb product   date
#  0        4272     460.0       3.14       7.80  Grapes  Jan 5
#  1        4272     243.0       1.57       3.93  Grapes  Jan 5
#  2        4272     186.0       2.59      12.55  Grapes  Jan 5
#  3        4272     196.0       2.97       6.06  Grapes  Jan 5
#  4        4272     472.0       0.84      17.17  Grapes  Jan 5
#  ..        ...       ...        ...        ...     ...    ...
#  133      4412     181.0       2.73       2.60    Pear  Jan 5
#  134      4412     469.0       1.92       4.58    Pear  Jan 5
#  135      4412     381.0       2.19      20.72    Pear  Jan 5
#  136      4159     214.0       0.80      21.91   Onion  Jan 5
#  137      4159     252.0       2.28       8.73   Onion  Jan 5
#
#  [138 rows x 6 columns],
#       prodcode  quantity  price_usd  weight_lb product    date
#  0        4272     356.0       3.11      16.08  Grapes  Jan 17
#  1        4272     312.0       3.14       6.37  Grapes  Jan 17
#  2        4272     246.0       2.55       9.70  Grapes  Jan 17
#  3        4272     262.0       2.32      19.86  Grapes  Jan 17
#  4        4958     335.0       1.85       7.44   Lemon  Jan 17
#  ..        ...       ...        ...        ...     ...     ...
#  142      4011     392.0       0.88      14.53  Banana  Jan 17
#  143      4011     442.0       0.74       4.96  Banana  Jan 17
#  144      4011     221.0       2.15       6.79  Banana  Jan 17
#  145      4011     486.0       0.79       2.38  Banana  Jan 17
#  146      4011     265.0       2.15       7.49  Banana  Jan 17
#
#  [147 rows x 6 columns],
#       prodcode  quantity  price_usd  weight_lb       product    date
#  0        4323     424.0       1.84      19.87  Strawberries  Jan 16
#  1        4323     491.0       1.80       4.84  Strawberries  Jan 16
#  2        4323     105.0       1.44      16.54  Strawberries  Jan 16
#  3        4323     327.0       3.09       5.76  Strawberries  Jan 16
#  4        4323     137.0       1.83       8.57  Strawberries  Jan 16
#  ..        ...       ...        ...        ...           ...     ...
#  159      4412     217.0       1.37      19.96          Pear  Jan 16
#  160      4412     143.0       1.89       7.77          Pear  Jan 16
#  161      4412     150.0       0.70       2.88          Pear  Jan 16
#  162      4412     426.0       2.53      16.68          Pear  Jan 16
#  163      4412     331.0       1.63      18.12          Pear  Jan 16
#
#  [164 rows x 6 columns],
#       prodcode  quantity  price_usd  weight_lb       product   date
#  0        4062     448.0       1.97      21.15      Cucumber  Jan 4
#  1        4062     227.0       2.76       4.76      Cucumber  Jan 4
#  2        4062     240.0       2.48      19.77      Cucumber  Jan 4
#  3        4062     119.0       1.51      14.54      Cucumber  Jan 4
#  4        4062     318.0       1.70      12.71      Cucumber  Jan 4
#  ..        ...       ...        ...        ...           ...    ...
#  145      4323     475.0       1.96      15.95  Strawberries  Jan 4
#  146      4323     324.0       1.68       4.44  Strawberries  Jan 4
#  147      4323     171.0       2.33      20.26  Strawberries  Jan 4
#  148      4323     180.0       1.36       8.34  Strawberries  Jan 4
#  149      4323     371.0       1.53      21.24  Strawberries  Jan 4
#
#  [150 rows x 6 columns],
#       prodcode  quantity  price_usd  weight_lb      product    date
#  0        4078     422.0       2.72      17.54         Corn  Jan 20
#  1        4078     168.0       1.03       9.60         Corn  Jan 20
#  2        4078     158.0       2.25       3.58         Corn  Jan 20
#  3        4078     341.0       1.88      13.49         Corn  Jan 20
#  4        4078     401.0       1.43      15.39         Corn  Jan 20
#  ..        ...       ...        ...        ...          ...     ...
#  164      4272     439.0       2.20       9.95       Grapes  Jan 20
#  165      4272     280.0       2.70      14.70       Grapes  Jan 20
#  166      4240     405.0       3.10      14.64  Blueberries  Jan 20
#  167      4240     220.0       2.06       3.89  Blueberries  Jan 20
#  168      4240     236.0       1.86      20.49  Blueberries  Jan 20
#
#  [169 rows x 6 columns],
#       prodcode  quantity  price_usd  weight_lb   product   date
#  0        4272     214.0       1.84      20.64    Grapes  Jan 8
#  1        4272     456.0       1.09      13.20    Grapes  Jan 8
#  2        4272     250.0       0.90      16.32    Grapes  Jan 8
#  3        4272     438.0       1.98       4.30    Grapes  Jan 8
#  4        4272     259.0       2.26      17.92    Grapes  Jan 8
#  ..        ...       ...        ...        ...       ...    ...
#  106      4650     122.0       2.00      20.86  Mushroom  Jan 8
#  107      4650     157.0       3.20      18.30  Mushroom  Jan 8
#  108      4796     313.0       2.87       3.60    Tomato  Jan 8
#  109      4796     380.0       0.70       6.62    Tomato  Jan 8
#  110      4796     298.0       3.15       4.80    Tomato  Jan 8
#
#  [111 rows x 6 columns]]

# %% [markdown]
# ### Step 5: Concatenate all DataFrames from Step 4 into one large DataFrame
# * _Hint:_ Is there a function in `pandas` that can do something like this for us? This is also just one line of code!

# %%
aust_list = pd.concat(aust_list)
aust_list.head()
# Out:
#    prodcode  quantity  price_usd  weight_lb product    date
# 0      4412     412.0       1.66      17.25    Pear  Jan 23
# 1      4412     334.0       0.65      10.43    Pear  Jan 23
# 2      4412     130.0       1.02      14.67    Pear  Jan 23
# 3      4412     459.0       0.64      14.20    Pear  Jan 23
# 4      4412     237.0       0.93      12.75    Pear  Jan 23

# %% [markdown]
# ### Step 6: Do this for all cities, write data to your output folder
# Here's the big one. For each city, process the data as in steps 3-5, and then write the data to your `output` folder. Below is a dictionary of city names to desired output file names.
#
# Before writing your DataFrame, do the following:
# * Add a `city` column
# * Reorder the columns into the following order:
#
#
# | city | date | product | prodcode | quantity | weight_lb | price_usd |
# |---|---|---|---|---|---|---|
#
# * _Hint:_ You can reorder DataFrame columns simply by writing over your DataFrame with itself, but specifying the specific column order with `.loc`. For example:
#
# `print(df)`
#
# | b | c | a |
# |---|---|---|
# | 1 | 2 | 3 |
#
# `df = df.loc[:, ["a", "b", "c"]]`
#
# `print(df)`
#
# | a | b | c |
# |---|---|---|
# | 3 | 1 | 2 |

# %%
city_dict = {
    "Atlanta": "atl.csv",
    "Austin": "atx.csv",
    "Boston": "bos.csv",
    "Chicago": "chi.csv",
    "Denver": "den.csv",
    "Los Angeles": "lax.csv",
    "New York": "nyc.csv",
    "San Francisco": "sf.csv",
    "Seattle": "sea.csv",
    "Washington, DC": "dc.csv"
}

# %%
# Loop through city_dict and carry out Step 6 here.
# The keys of city_dict can serve as the sheet name.
# The values of city_dict are what you should name the output .csv files.
# If done correctly, this cell could take almost a minute to run!

for k, v in city_dict.items():
    df = [process_data(x, k) for x in files]
    df = pd.concat(df)
    df['city'] = k
    df = df[['city','date','product','prodcode','quantity','weight_lb','price_usd']]
    df.to_csv(f'./output/{v}', index=False)
# Out:
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
# ...
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Users/josedelgadillo/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %% [markdown]
# # Part II: Checking our answers
# In steps very similar to the ones conducted above...
# 1. Loop through the files we just wrote to `output`, and read them in, collecting them all in one list _(Hint: Using the `os` library and a list comprehension would make this 1-2 lines of code!)_
# 1. Combine all of those DataFrames into one large DataFrame
# 1. For each city, find the mean `quantity`, `weight_lb`, and `price_usd`.
#
# If you've done everything correct, your answer should look exactly like this:
#
# ![](imgs/correct-output.png)

# %%
files2 = os.listdir(path='./output')
output_list = [pd.read_csv('./output/' + x) for x in files2]

# %%
output_df = pd.concat(output_list)
output_df.head()
# Out:
#           city    date product  prodcode  quantity  weight_lb  price_usd
# 0  Los Angeles  Jan 23   Lemon      4958     263.0      12.16       2.88
# 1  Los Angeles  Jan 23   Lemon      4958     222.0      21.17       1.49
# 2  Los Angeles  Jan 23   Lemon      4958     355.0      13.46       2.24
# 3  Los Angeles  Jan 23   Lemon      4958     101.0      11.64       1.30
# 4  Los Angeles  Jan 23   Lemon      4958     185.0      10.65       1.49

# %%
output_df.groupby('city')['quantity', 'weight_lb', 'price_usd'].mean()
# Out:
# /var/folders/6t/85msmsnj1ksb3tpnsplp1bc00000gn/T/ipykernel_28041/3460969745.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   output_df.groupby('city')['quantity', 'weight_lb', 'price_usd'].mean()
#                   quantity  weight_lb  price_usd
# city
# Atlanta         302.485306  11.929030   1.937941
# Austin          301.048298  12.092691   1.937411
# Boston          298.806536  12.063041   1.900989
# Chicago         301.686186  12.101508   1.930013
# Denver          301.012745  12.129856   1.932148
# Los Angeles     301.531276  12.167558   1.918300
# New York        299.482863  12.090272   1.912690
# San Francisco   298.979895  12.237426   1.925807
# Seattle         300.333694  11.925484   1.903276
# Washington, DC  300.576421  11.930783   1.943132

# %% [markdown]
# # Part III (BONUS): Get this process production-ready!
# _This part of the lab is optional, but very highly recommended, as the skills developed in this part are extremely common in industry._
#
# For this step, we're going to take this whole process and put it into a production-ready Python script. **ABSOLUTELY NONE OF THIS STEP SHOULD TAKE PLACE IN A JUPYTER NOTEBOOK! PRODUCTIONALIZED ETL (_"Extract, Transform, Load"_) CODE DOES NOT TAKE PLACE IN A JUPYTER NOTEBOOK!**
#
# The instructions are simple: As conducted in this lab, read, transform, and export the data in our Excel files into .csv files. The code should be in a `.py` file (editable in any text editor) and executable from the command line. Here are some hints and tips to guide you:
#
# ### Hints, tips, and tricks:
# * A good place to start is with the code you've already written. In this notebook, you can click `File > Download as > Python (.py)` to export as a `.py` file. Most of this exercise then comes down to you cleaning this file. (There will be a lot to clean).
# * Remember `os.mkdir()` will throw an error if the folder you're trying to make already exists. Maybe you should check to see if it already exists. If it already exists, what should you do? (Remember that `.csv` can be overwritten with no problem.) The functions that can help you with this are all in the `os` library.
# * Remember to follow all of the Python best practices we've already learned:
#     - All import statements should go at the top of your script.
#     - **Comment your code.** Comments shouldn't explain _what_ code does, but _why_ the code does this.
#     - Keep your code DRY (don't repeat yourself) as opposed to WET (write everything twice). All constants should be variables that only need to be changed once. All code should be bottled into functions so you only need to fix it once.
# * Make sure not to hardcode "Jan" anywhere. The point is that this code can be run throughout the lifetime of this supermarket's project, which is likely months or years. Keep your code so that if you get February data, you only need to change one tiny piece of the script (probably a file path).
